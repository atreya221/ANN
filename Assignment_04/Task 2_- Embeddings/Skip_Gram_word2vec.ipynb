# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](https://github.com/atreya221/Project_Submission_ANN_SC/blob/master/Assignment_04/Task%202_-%20Embeddings/assets/one_hot_encoding.png?raw=1)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](https://github.com/atreya221/Project_Submission_ANN_SC/blob/master/Assignment_04/Task%202_-%20Embeddings/assets/lookup_matrix.png?raw=1)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='https://github.com/atreya221/Project_Submission_ANN_SC/blob/master/Assignment_04/Task%202_-%20Embeddings/assets/tokenize_lookup.png?raw=1' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="https://github.com/atreya221/Project_Submission_ANN_SC/blob/master/Assignment_04/Task%202_-%20Embeddings/assets/word2vec_architectures.png?raw=1" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
# %tensorflow_version 1.x

import numpy as np
import tensorflow as tf

import utils
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(t/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 4629682

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,window_size + 1)
    if (idx-R)>0:
      start = idx-R
    else:
      start = 0
    stop = idx + R
    target = []
    for i in range(idx-window_size,idx+window_size+1):
      target_words = set(words[start:idx] + words[idx+1:stop+1])
    target = list(target_words)
    
    return target

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](https://github.com/atreya221/Project_Submission_ANN_SC/blob/master/Assignment_04/Task%202_-%20Embeddings/assets/skip_gram_net_arch.png?raw=1)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape = [None])
    labels = tf.placeholder(dtype=tf.int32, shape = [None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6335 0.0698 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6088 0.0514 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5172 0.0518 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5787 0.0514 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5021 0.0514 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4952 0.0510 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5801 0.0515 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5772 0.0516 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4773 0.0524 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4009 0.0527 sec/batch
# Nearest to that: attract, bards, legislature, continuants, shipwrecks, titans, calorimetry, gneisenau,
# Nearest to called: kolberg, giorgio, marcia, swabian, wirtschaftswunder, ts, maranh, wavelengths,
# Nearest to history: ananias, encounter, prisons, bio, prokofiev, platz, vald, doppelbock,
# Nearest to the: within, jew, wands, celebritarian, stokes, lgiy, nominating, fingernails,
# Nearest to has: zahir, monsieur, diversified, prototyping, prefigured, answered, sought, skyhawk,
# Nearest to american: neutrinos, inuktitut, aa, uniformity, niqqud, award, cyanide, baptists,
# Nearest to have: waterway, paved, decoder, quipped, vee, sligo, dks, erroneously,
# Nearest to will: coe, disciplines, geek, mondays, schedules, rev, apostles, swaziland,
# Nearest to articles: juxtaposed, sitar, kliment, severely, healer, beiderbecke, stabilise, dominance,
# Nearest to defense: jilted, monogatari, missile, secretes, carvey, produced, separator, shelled,
# Nearest to hold: sixes, unlikely, taxonomic, copyists, flirty, sensor, oncoming, ascari,
# Nearest to experience: disquisitiones, declawed, barroso, conflation, drabble, kn, rags, fears,
# Nearest to pressure: bonilla, labiodental, opteron, dogg, copyrights, airliner, clave, regrouping,
# Nearest to ocean: trnc, xserve, bely, lease, literary, representing, iggy, bohemian,
# Nearest to issue: subgenius, vara, afesd, cuvier, solvent, repealed, masks, multipoint,
# Nearest to cost: contemplative, curds, authorization, creatures, respected, flawed, bulwark, skyrocketed,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4800 0.0538 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3960 0.0511 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3385 0.0514 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2493 0.0512 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2057 0.0516 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1376 0.0512 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0965 0.0513 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0842 0.0512 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0094 0.0511 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9696 0.0509 sec/batch
# Nearest to that: attract, legislature, measure, derived, bards, sizeable, least, exclusion,
# Nearest to called: giorgio, substance, kolberg, furthermore, fiction, marcia, capital, beatles,
# Nearest to history: encounter, prisons, bio, provides, prokofiev, image, multiple, italy,
# Nearest to the: within, jew, evolution, substantially, wands, stokes, merchants, argued,
# Nearest to has: diversified, sought, supportive, answered, advocates, earthworms, performance, skyhawk,
# Nearest to american: award, uniformity, neutrinos, about, neighbors, aa, lifetime, signing,
# Nearest to have: paved, individuals, waterway, quipped, decoder, erroneously, benefits, know,
# Nearest to will: hard, coe, geek, disciplines, shorts, rev, swaziland, schedules,
# Nearest to articles: severely, juxtaposed, kliment, techniques, sitar, neglect, seasonal, dominance,
# Nearest to defense: jilted, produced, monogatari, carvey, missile, higher, sealed, secularized,
# Nearest to hold: unlikely, sixes, task, switch, structures, utilized, until, sensor,
# Nearest to experience: disquisitiones, magi, declawed, fears, flowers, firewalls, comet, fail,
# Nearest to pressure: bonilla, romania, copyrights, sit, labiodental, muscular, dogg, regionally,
# Nearest to ocean: trnc, modern, iggy, literary, prompts, representing, xserve, bely,
# Nearest to issue: subgenius, usually, vara, solvent, ancestor, masks, cuvier, repealed,
# Nearest to cost: flawed, authorization, creatures, respected, those, contemplative, very, curds,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9402 0.0525 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8925 0.0514 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9185 0.0515 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8814 0.0512 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8072 0.0513 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8256 0.0514 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8018 0.0514 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7848 0.0514 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7608 0.0513 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7684 0.0514 sec/batch
# Nearest to that: attract, bards, legislature, objects, measure, ciphertext, exclusion, derived,
# Nearest to called: giorgio, kolberg, fiction, furthermore, marcia, beatles, substance, unitary,
# Nearest to history: encounter, prisons, bio, italy, prokofiev, fond, fitch, ananias,
# Nearest to the: within, stokes, substantially, merchants, wands, flag, closes, courage,
# Nearest to has: diversified, prototyping, answered, sought, supportive, advocates, zahir, earthworms,
# Nearest to american: award, uniformity, neutrinos, aa, neighbors, cyanide, lifetime, signing,
# Nearest to have: paved, decoder, waterway, individuals, quipped, benefits, erroneously, dks,
# Nearest to will: coe, hard, schedules, rev, geek, disciplines, apostles, resentful,
# Nearest to articles: severely, juxtaposed, sitar, techniques, dominance, neglect, stabilise, kliment,
# Nearest to defense: produced, monogatari, jilted, missile, carvey, sealed, shelled, higher,
# Nearest to hold: unlikely, sixes, utilized, task, sensor, taxonomic, ascari, copyists,
# Nearest to experience: disquisitiones, fears, magi, fail, firewalls, comet, rags, declawed,
# Nearest to pressure: bonilla, specify, copyrights, labiodental, papacy, dogg, haast, poison,
# Nearest to ocean: trnc, modern, iggy, prompts, literary, representing, bely, xserve,
# Nearest to issue: subgenius, locus, cuvier, vara, ancestor, repealed, usually, miguel,
# Nearest to cost: authorization, respected, flawed, creatures, yap, curds, very, contemplative,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7981 0.0521 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7589 0.0512 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6946 0.0511 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7298 0.0510 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7398 0.0514 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6982 0.0516 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7351 0.0512 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7360 0.0513 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6994 0.0510 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6398 0.0511 sec/batch
# Nearest to that: attract, bards, shipwrecks, ciphertext, isa, objects, titans, legislature,
# Nearest to called: kolberg, giorgio, substance, fiction, marcia, furthermore, unitary, beatles,
# Nearest to history: encounter, prisons, bio, prokofiev, fond, vichy, italy, ananias,
# Nearest to the: within, closes, stokes, merchants, nominating, substantially, flag, wands,
# Nearest to has: diversified, prototyping, advocates, supportive, answered, zahir, sought, multilateral,
# Nearest to american: award, chemist, neutrinos, baptists, aa, captained, uniformity, hirsch,
# Nearest to have: decoder, benefits, individuals, know, dks, sages, waterway, expansionary,
# Nearest to will: rev, hard, coe, schedules, disciplines, geek, holst, mondays,
# Nearest to articles: severely, juxtaposed, sitar, stabilise, dominance, healer, romanesque, neglect,
# Nearest to defense: missile, monogatari, produced, jilted, carvey, tonight, sealed, nonfiction,
# Nearest to hold: sixes, unlikely, oncoming, taxonomic, symptoms, sensor, ascari, copyists,
# Nearest to experience: disquisitiones, magi, firewalls, fail, fears, declawed, conflation, flowers,
# Nearest to pressure: bonilla, airliner, specify, labiodental, copyrights, opteron, clave, poison,
# Nearest to ocean: trnc, modern, bely, prompts, tackle, iggy, literary, sundarbans,
# Nearest to issue: subgenius, locus, cuvier, vara, ancestor, miguel, glace, hilt,
# Nearest to cost: authorization, contemplative, respected, creatures, flawed, brittle, curds, persuasive,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6783 0.0523 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6560 0.0514 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5940 0.0513 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6483 0.0513 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6249 0.0512 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6520 0.0515 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5710 0.0366 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5778 0.0514 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5115 0.0514 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4873 0.0515 sec/batch
# Nearest to that: attract, bards, shipwrecks, ciphertext, isa, objects, titans, continuants,
# Nearest to called: kolberg, giorgio, furthermore, substance, marcia, unitary, fiction, maranh,
# Nearest to history: prisons, encounter, ananias, prokofiev, bio, palembang, crabbe, boardgamegeek,
# Nearest to the: within, closes, stokes, wands, nominating, celebritarian, merchants, substantially,
# Nearest to has: diversified, prototyping, multilateral, answered, zahir, supportive, advocates, skyhawk,
# Nearest to american: chemist, journalist, award, novelist, williams, baptists, writer, hirsch,
# Nearest to have: decoder, benefits, sages, ponder, requiem, undermines, know, individuals,
# Nearest to will: hard, schedules, holst, rev, stable, disciplines, basics, intersection,
# Nearest to articles: sitar, juxtaposed, severely, stabilise, romanesque, troja, beiderbecke, anglicanism,
# Nearest to defense: missile, produced, monogatari, jilted, docs, sealed, carvey, separator,
# Nearest to hold: sixes, unlikely, taxonomic, oncoming, symptoms, copyists, ascari, spirits,
# Nearest to experience: disquisitiones, firewalls, fail, declawed, magi, conflation, barroso, rags,
# Nearest to pressure: airliner, bonilla, opteron, regrouping, clave, copyrights, labiodental, specify,
# Nearest to ocean: modern, sundarbans, trnc, prompts, bely, tackle, aaas, reservists,
# Nearest to issue: subgenius, locus, cuvier, vara, hilt, miguel, ancestor, glace,
# Nearest to cost: authorization, contemplative, rabat, brittle, very, ability, creatures, filaments,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5101 0.0522 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5002 0.0514 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4694 0.0513 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4996 0.0513 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4980 0.0513 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4647 0.0513 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4503 0.0513 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3798 0.0515 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4213 0.0511 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4552 0.0514 sec/batch
# Nearest to that: attract, ciphertext, objects, shipwrecks, bards, panth, wondered, recurred,
# Nearest to called: kolberg, substance, furthermore, giorgio, maranh, unitary, wirtschaftswunder, charger,
# Nearest to history: prisons, whims, prokofiev, fitch, crabbe, encounter, vald, junior,
# Nearest to the: within, wands, closes, substantially, nominating, its, immunised, celebritarian,
# Nearest to has: diversified, prototyping, multilateral, supportive, advocates, laos, skyhawk, appeasing,
# Nearest to american: award, chemist, williams, journalist, hirsch, novelist, baptists, captained,
# Nearest to have: individuals, benefits, decoder, undermines, ponder, brits, sages, know,
# Nearest to will: hard, schedules, holst, disciplines, stable, geek, intersection, accomplishing,
# Nearest to articles: sitar, juxtaposed, severely, stabilise, romanesque, troja, anglicanism, verdean,
# Nearest to defense: missile, monogatari, produced, jilted, sealed, docs, separator, jure,
# Nearest to hold: sixes, unlikely, oncoming, taxonomic, copyists, spirits, symptoms, nir,
# Nearest to experience: disquisitiones, fail, firewalls, conflation, drabble, persist, magi, declawed,
# Nearest to pressure: airliner, bonilla, opteron, clave, liquid, regrouping, labiodental, specify,
# Nearest to ocean: sundarbans, warm, modern, aaas, northward, trnc, bely, markets,
# Nearest to issue: subgenius, locus, cuvier, vara, hilt, explosively, proconsul, glace,
# Nearest to cost: authorization, contemplative, brittle, rabat, yoho, very, ability, plummet,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4436 0.0526 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4151 0.0515 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4313 0.0511 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3796 0.0514 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4016 0.0515 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4462 0.0516 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3687 0.0514 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3609 0.0519 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4260 0.0516 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3420 0.0525 sec/batch
# Nearest to that: attract, ciphertext, shipwrecks, bards, panth, investigate, objects, wondered,
# Nearest to called: kolberg, substance, maranh, furthermore, giorgio, charger, schematic, unitary,
# Nearest to history: philosophy, prisons, fitch, ananias, whims, palembang, crabbe, prokofiev,
# Nearest to the: within, wands, its, nominating, deseret, closes, immunised, celebritarian,
# Nearest to has: diversified, prototyping, supportive, advocates, multilateral, inserting, facilitates, generic,
# Nearest to american: williams, chemist, award, hirsch, journalist, tyrannical, captained, novelist,
# Nearest to have: individuals, benefits, dks, know, undermines, decoder, ponder, brits,
# Nearest to will: hard, schedules, disciplines, accomplishing, ready, stable, pebbles, lego,
# Nearest to articles: juxtaposed, sitar, severely, anglicanism, stabilise, romanesque, crocker, troja,
# Nearest to defense: missile, monogatari, produced, docs, jilted, sealed, jure, equites,
# Nearest to hold: sixes, unlikely, symptoms, taxonomic, oncoming, copyists, nir, jailer,
# Nearest to experience: disquisitiones, fail, conflation, drabble, declawed, persist, firewalls, rags,
# Nearest to pressure: airliner, bonilla, opteron, regrouping, liquid, clave, poison, reaction,
# Nearest to ocean: sundarbans, northward, warm, extends, northeast, coastlines, polluted, bely,
# Nearest to issue: subgenius, explosively, locus, vara, cuvier, hilt, ancestor, overhauled,
# Nearest to cost: authorization, yoho, rabat, plummet, brittle, ability, contemplative, very,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3375 0.0534 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3852 0.0513 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3465 0.0512 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3851 0.0511 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3914 0.0513 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3794 0.0513 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3827 0.0511 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3709 0.0511 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3423 0.0508 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3151 0.0512 sec/batch
# Nearest to that: attract, shipwrecks, ciphertext, bards, panth, investigate, objects, conciliation,
# Nearest to called: kolberg, substance, unitary, wirtschaftswunder, charger, furthermore, maranh, mens,
# Nearest to history: philosophy, prisons, vichy, ananias, crabbe, whims, palembang, bio,
# Nearest to the: within, its, deseret, of, closes, nominating, wands, flag,
# Nearest to has: diversified, prototyping, advocates, multilateral, supportive, laos, generic, appeasing,
# Nearest to american: hirsch, williams, award, tyrannical, journalist, chemist, forsyth, captained,
# Nearest to have: know, individuals, benefits, nicomachean, undermines, ponder, dks, expansionary,
# Nearest to will: ready, schedules, hard, disciplines, grapevines, accomplishing, mondays, heritability,
# Nearest to articles: juxtaposed, sitar, anglicanism, crocker, stabilise, troja, links, romanesque,
# Nearest to defense: missile, monogatari, produced, docs, sealed, jure, federline, jilted,
# Nearest to hold: sixes, unlikely, oncoming, symptoms, just, nir, anything, copyists,
# Nearest to experience: disquisitiones, fail, conflation, humanistic, declawed, drabble, magi, persist,
# Nearest to pressure: airliner, bonilla, clave, regrouping, poison, opteron, liquid, labiodental,
# Nearest to ocean: sundarbans, northward, extends, northeast, coastlines, southwestern, warm, zambia,
# Nearest to issue: subgenius, explosively, vara, hilt, proconsul, pontifical, cuvier, overhauled,
# Nearest to cost: authorization, yoho, brittle, ability, rabat, contemplative, plummet, very,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3754 0.0521 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2826 0.0516 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3734 0.0513 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3831 0.0513 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3953 0.0511 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2946 0.0512 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3229 0.0509 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3528 0.0513 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2295 0.0512 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3014 0.0512 sec/batch
# Nearest to that: attract, ciphertext, investigate, shipwrecks, panth, objects, recurred, bards,
# Nearest to called: kolberg, unitary, furthermore, wirtschaftswunder, maranh, mens, logging, substance,
# Nearest to history: philosophy, crabbe, megalithic, ananias, prisons, bio, vald, whims,
# Nearest to the: within, deseret, closes, its, of, chagos, assembly, nhra,
# Nearest to has: diversified, laos, multilateral, prototyping, supportive, appeasing, generic, advocates,
# Nearest to american: williams, chemist, journalist, hirsch, tyrannical, forsyth, novelist, canadian,
# Nearest to have: know, individuals, benefits, ponder, nicomachean, dks, undermines, expansionary,
# Nearest to will: ready, hard, schedules, mondays, grapevines, accomplishing, holst, disciplines,
# Nearest to articles: juxtaposed, sitar, links, stabilise, anglicanism, troja, romanesque, crocker,
# Nearest to defense: missile, monogatari, jure, produced, sealed, docs, federline, soli,
# Nearest to hold: unlikely, sixes, oncoming, nir, cmavo, copyists, just, anything,
# Nearest to experience: disquisitiones, fail, conflation, humanistic, drabble, declawed, themes, persist,
# Nearest to pressure: airliner, regrouping, poison, bonilla, clave, labiodental, liquid, liberalisation,
# Nearest to ocean: sundarbans, extends, zambia, northward, coastlines, northeast, southwestern, warm,
# Nearest to issue: subgenius, explosively, pontifical, vara, hilt, proconsul, cuvier, glace,
# Nearest to cost: authorization, yoho, brittle, contemplative, police, market, deficit, expander,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3100 0.0520 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3172 0.0514 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3310 0.0220 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2488 0.0511 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2517 0.0514 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2275 0.0513 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2083 0.0518 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2219 0.0516 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2147 0.0516 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1772 0.0512 sec/batch
# Nearest to that: attract, investigate, shipwrecks, ciphertext, revlon, profitability, panth, kq,
# Nearest to called: kolberg, unitary, furthermore, wirtschaftswunder, messier, mens, logging, charger,
# Nearest to history: crabbe, bio, ananias, megalithic, philosophy, whims, peek, st,
# Nearest to the: within, of, deseret, chagos, its, closes, bolero, awaiting,
# Nearest to has: diversified, laos, supportive, diners, prototyping, lesotho, garnered, walkers,
# Nearest to american: hirsch, chemist, journalist, williams, forsyth, canadian, tyrannical, boxer,
# Nearest to have: ponder, individuals, know, benefits, nozzle, expansionary, nitijela, undermines,
# Nearest to will: ready, effectively, schedules, grapevines, mondays, holst, hard, pebbles,
# Nearest to articles: juxtaposed, sitar, links, stabilise, anglicanism, crocker, troja, romanesque,
# Nearest to defense: missile, monogatari, sealed, produced, docs, jure, safety, federline,
# Nearest to hold: unlikely, sixes, oncoming, copyists, nir, without, just, cmavo,
# Nearest to experience: fail, drabble, conflation, disquisitiones, apostolicity, humanistic, distress, minds,
# Nearest to pressure: airliner, poison, bonilla, regrouping, clave, liquid, substrates, maw,
# Nearest to ocean: extends, sundarbans, zambia, northward, coastlines, ridge, southwestern, atlantic,
# Nearest to issue: subgenius, hilt, explosively, proconsul, vara, cuvier, prosecuted, pontifical,
# Nearest to cost: authorization, market, brittle, upgraded, contemplative, police, yoho, skyrocketed,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2343 0.0527 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2225 0.0516 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2227 0.0514 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1456 0.0512 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1649 0.0513 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1676 0.0511 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1707 0.0509 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1734 0.0513 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1990 0.0513 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1692 0.0514 sec/batch
# Nearest to that: investigate, ciphertext, attract, shipwrecks, accumulator, urinate, revlon, wondered,
# Nearest to called: kolberg, furthermore, messier, unitary, substance, charger, wirtschaftswunder, mens,
# Nearest to history: philosophy, bio, megalithic, crabbe, ananias, prisons, image, st,
# Nearest to the: within, of, deseret, banias, nhra, closes, flag, submerged,
# Nearest to has: diversified, prototyping, supportive, prefigured, appeasing, advocates, cerebrum, laos,
# Nearest to american: hirsch, chemist, journalist, forsyth, living, tonga, tyrannical, janet,
# Nearest to have: know, individuals, ponder, nozzle, benefits, nicomachean, undermines, nitijela,
# Nearest to will: ready, accomplishing, grapevines, said, effectively, hard, pebbles, schedules,
# Nearest to articles: juxtaposed, links, sitar, stabilise, anglicanism, troja, crocker, forum,
# Nearest to defense: missile, monogatari, sealed, produced, docs, jure, federline, equites,
# Nearest to hold: unlikely, sixes, oncoming, copyists, without, nir, anything, task,
# Nearest to experience: drabble, conflation, fail, disquisitiones, apostolicity, rags, minds, declawed,
# Nearest to pressure: airliner, poison, liquid, bonilla, regrouping, clave, displacements, labiodental,
# Nearest to ocean: sundarbans, extends, zambia, coastlines, northward, atlantic, ridge, southwestern,
# Nearest to issue: subgenius, explosively, hilt, proconsul, prosecuted, pontifical, examiners, matters,
# Nearest to cost: authorization, market, very, contemplative, brittle, yoho, police, overall,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1647 0.0524 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2064 0.0512 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2027 0.0512 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1550 0.0510 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1900 0.0511 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1675 0.0511 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1951 0.0515 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1479 0.0512 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1127 0.0512 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1785 0.0509 sec/batch
# Nearest to that: investigate, shipwrecks, ciphertext, panth, attract, wondered, urinate, bards,
# Nearest to called: kolberg, unitary, messier, wirtschaftswunder, furthermore, rigel, charger, mens,
# Nearest to history: philosophy, bio, ananias, crabbe, megalithic, publish, prisons, textbooks,
# Nearest to the: within, of, deseret, substantially, flag, assembly, chagos, sov,
# Nearest to has: diversified, prototyping, supportive, multilateral, laos, generic, facilitates, appeasing,
# Nearest to american: journalist, hirsch, forsyth, chemist, janet, boxer, tyrannical, vince,
# Nearest to have: know, ponder, nozzle, aorist, erichthonius, individuals, nicomachean, nitijela,
# Nearest to will: ready, committed, said, effectively, accomplishing, busy, constructive, grapevines,
# Nearest to articles: juxtaposed, links, sitar, stabilise, anglicanism, crocker, forum, internet,
# Nearest to defense: missile, monogatari, sealed, docs, jure, produced, federline, equites,
# Nearest to hold: unlikely, sixes, copyists, oncoming, just, without, only, cmavo,
# Nearest to experience: conflation, fail, disquisitiones, drabble, humanistic, declawed, apostolicity, minds,
# Nearest to pressure: poison, airliner, liquid, bonilla, displacements, regrouping, labiodental, clave,
# Nearest to ocean: sundarbans, extends, zambia, atlantic, coastlines, northward, shortwave, southwestern,
# Nearest to issue: subgenius, explosively, pontifical, proconsul, hilt, miguel, examiners, prosecuted,
# Nearest to cost: market, authorization, very, yoho, brittle, upgraded, plummet, kalashnikov,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1877 0.0524 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1871 0.0514 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1692 0.0512 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1882 0.0513 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1335 0.0516 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1233 0.0515 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1816 0.0515 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1475 0.0526 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1967 0.0516 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2090 0.0519 sec/batch
# Nearest to that: investigate, panth, shipwrecks, attract, urinate, revlon, wondered, bards,
# Nearest to called: kolberg, unitary, wirtschaftswunder, mens, malory, charger, furthermore, messier,
# Nearest to history: philosophy, bio, crabbe, ananias, megalithic, image, st, textbooks,
# Nearest to the: of, within, deseret, assembly, and, presided, its, substantially,
# Nearest to has: diversified, prototyping, supportive, laos, multilateral, prefigured, skilfully, diners,
# Nearest to american: hirsch, forsyth, chemist, living, boxer, journalist, canadian, congresswoman,
# Nearest to have: know, ponder, aorist, nitijela, nozzle, nicomachean, erichthonius, childrearing,
# Nearest to will: ready, apostles, mondays, said, grapevines, committed, accomplishing, tura,
# Nearest to articles: juxtaposed, links, sitar, anglicanism, dossier, troja, stabilise, crocker,
# Nearest to defense: missile, monogatari, sealed, jure, docs, equites, produced, rumsfeld,
# Nearest to hold: unlikely, sixes, copyists, oncoming, without, just, only, circumventing,
# Nearest to experience: conflation, disquisitiones, drabble, declawed, fail, apostolicity, humanistic, cornerstones,
# Nearest to pressure: airliner, poison, bonilla, displacements, liquid, regrouping, labiodental, clave,
# Nearest to ocean: sundarbans, zambia, atlantic, extends, coastlines, northward, dar, southwestern,
# Nearest to issue: subgenius, pontifical, miguel, proconsul, prosecuted, explosively, vara, hilt,
# Nearest to cost: authorization, yoho, market, contemplative, yeo, dateline, deficit, kalashnikov,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2507 0.0538 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1545 0.0524 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1262 0.0516 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1489 0.0519 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0456 0.0515 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1577 0.0517 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1470 0.0513 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1329 0.0517 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1655 0.0073 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1513 0.0515 sec/batch
# Nearest to that: investigate, attract, shipwrecks, urinate, profitability, kq, ciphertext, wondered,
# Nearest to called: unitary, kolberg, messier, wirtschaftswunder, maranh, charger, mens, furthermore,
# Nearest to history: bio, philosophy, ananias, crabbe, image, peek, st, megalithic,
# Nearest to the: of, within, deseret, and, its, substantially, in, banias,
# Nearest to has: diversified, prototyping, lesotho, generic, garnered, geophysical, laos, diners,
# Nearest to american: hirsch, chemist, journalist, forsyth, living, canadian, boxer, congresswoman,
# Nearest to have: know, nozzle, aorist, ponder, nitijela, researchers, mspf, expansionary,
# Nearest to will: ready, mondays, said, apostles, random, constructive, rev, committed,
# Nearest to articles: juxtaposed, links, sitar, stabilise, dossier, anglicanism, troja, forum,
# Nearest to defense: missile, sealed, monogatari, jure, docs, offense, equites, produced,
# Nearest to hold: unlikely, sixes, copyists, oncoming, without, circumventing, cmavo, pleading,
# Nearest to experience: conflation, humanistic, apostolicity, drabble, cornerstones, phodopus, minds, rags,
# Nearest to pressure: poison, airliner, bonilla, displacements, regrouping, labiodental, liquid, maw,
# Nearest to ocean: sundarbans, zambia, atlantic, coastlines, extends, trnc, southwestern, ghats,
# Nearest to issue: subgenius, explosively, appeal, prosecuted, pontifical, vara, miguel, examiners,
# Nearest to cost: market, upgraded, authorization, yoho, contemplative, yeo, dateline, very,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0925 0.0524 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0808 0.0514 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0926 0.0516 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0447 0.0514 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0872 0.0512 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0562 0.0511 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1224 0.0511 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0856 0.0513 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1259 0.0511 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0447 0.0514 sec/batch
# Nearest to that: urinate, investigate, shipwrecks, accumulator, attract, republika, letterboxes, revlon,
# Nearest to called: unitary, kolberg, messier, wirtschaftswunder, quail, charger, maranh, spanish,
# Nearest to history: bio, philosophy, ananias, crabbe, jordanes, kenney, image, latrobe,
# Nearest to the: of, within, its, and, in, deseret, banias, substantially,
# Nearest to has: diversified, prototyping, garnered, synthesiser, supportive, lesotho, generic, geophysical,
# Nearest to american: hirsch, living, forsyth, journalist, chemist, canadian, congresswoman, tonga,
# Nearest to have: know, ponder, researchers, nozzle, mspf, nitijela, aorist, individuals,
# Nearest to will: ready, mondays, apostles, random, said, pumped, busy, constructive,
# Nearest to articles: juxtaposed, links, sitar, dossier, anglicanism, stabilise, troja, crocker,
# Nearest to defense: missile, sealed, monogatari, jure, offense, equites, produced, specialized,
# Nearest to hold: unlikely, oncoming, copyists, sixes, without, pleading, cmavo, circumventing,
# Nearest to experience: conflation, rags, drabble, cornerstones, fail, humanistic, minds, heidi,
# Nearest to pressure: poison, airliner, displacements, labiodental, bonilla, liquid, regrouping, vapor,
# Nearest to ocean: sundarbans, atlantic, zambia, extends, coastlines, ghats, southwestern, polluted,
# Nearest to issue: subgenius, prosecuted, miguel, dhahran, limehouse, examiners, explosively, matters,
# Nearest to cost: authorization, yeo, very, upgraded, dateline, market, contemplative, skyrocketed,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0162 0.0520 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0116 0.0509 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0513 0.0509 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0697 0.0510 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0601 0.0512 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0523 0.0511 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0349 0.0513 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1073 0.0517 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0772 0.0514 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0385 0.0512 sec/batch
# Nearest to that: investigate, the, urinate, ciphertext, shipwrecks, accumulator, morphisms, letterboxes,
# Nearest to called: unitary, kolberg, messier, furthermore, wirtschaftswunder, perinatal, substance, handset,
# Nearest to history: bio, philosophy, ananias, image, crabbe, peek, jordanes, ceramics,
# Nearest to the: of, within, in, its, substantially, deseret, and, that,
# Nearest to has: prototyping, diversified, supportive, synthesiser, laos, summary, garnered, skilfully,
# Nearest to american: hirsch, living, journalist, forsyth, chemist, canadian, sennett, tonga,
# Nearest to have: know, nozzle, researchers, mspf, nitijela, ponder, nicomachean, wafers,
# Nearest to will: ready, mondays, apostles, constructive, random, pumped, busy, come,
# Nearest to articles: links, juxtaposed, sitar, stabilise, dossier, anglicanism, crocker, windows,
# Nearest to defense: missile, sealed, monogatari, offense, equites, rumsfeld, docs, produced,
# Nearest to hold: unlikely, oncoming, copyists, sixes, without, only, cmavo, sensitivities,
# Nearest to experience: conflation, humanistic, rags, drabble, minds, cornerstones, fail, disquisitiones,
# Nearest to pressure: poison, displacements, liquid, airliner, raman, vapor, labiodental, bonilla,
# Nearest to ocean: sundarbans, atlantic, zambia, coastlines, extends, trnc, shortwave, polluted,
# Nearest to issue: subgenius, dhahran, explosively, prosecuted, samoans, checked, locus, miguel,
# Nearest to cost: market, very, pentium, overall, skyrocketed, deficit, dateline, upgraded,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0459 0.0521 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0728 0.0508 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0605 0.0512 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0629 0.0512 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0776 0.0507 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0145 0.0514 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0451 0.0510 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0674 0.0514 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1028 0.0508 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0324 0.0512 sec/batch
# Nearest to that: monotheistic, urinate, investigate, republika, shipwrecks, dominus, the, ciphertext,
# Nearest to called: kolberg, unitary, wirtschaftswunder, maranh, charger, damasus, messier, each,
# Nearest to history: jordanes, ananias, bio, philosophy, crabbe, italy, image, golconda,
# Nearest to the: of, within, its, in, and, from, deseret, substantially,
# Nearest to has: prototyping, synthesiser, garnered, diversified, whorehouse, skilfully, blackball, supportive,
# Nearest to american: living, hirsch, forsyth, journalist, chemist, canadian, sennett, congresswoman,
# Nearest to have: know, ponder, nicomachean, wonderful, nitijela, aorist, surpassed, folklore,
# Nearest to will: ready, mondays, apostles, come, busy, god, pending, committed,
# Nearest to articles: links, juxtaposed, sitar, crocker, dossier, troja, newspaper, anglicanism,
# Nearest to defense: missile, sealed, monogatari, jure, docs, rumsfeld, equites, offense,
# Nearest to hold: unlikely, without, copyists, oncoming, sixes, only, just, circumventing,
# Nearest to experience: humanistic, conflation, cornerstones, drabble, fail, rags, phodopus, minds,
# Nearest to pressure: poison, displacements, liquid, airliner, raman, vapor, bonilla, polishing,
# Nearest to ocean: sundarbans, atlantic, zambia, trnc, shortwave, coastlines, satellite, freeways,
# Nearest to issue: subgenius, samoans, pontifical, miguel, dhahran, prosecuted, boldness, explosively,
# Nearest to cost: very, dateline, authorization, upgraded, market, yeo, endorsement, plummet,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0561 0.0522 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0146 0.0512 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0692 0.0511 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0905 0.0514 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0397 0.0513 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1140 0.0513 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1337 0.0515 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0786 0.0515 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0062 0.0513 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0483 0.0511 sec/batch
# Nearest to that: urinate, shipwrecks, the, ciphertext, investigate, accumulator, revlon, monotheistic,
# Nearest to called: unitary, kolberg, each, wirtschaftswunder, damasus, handset, messier, maranh,
# Nearest to history: bio, ananias, crabbe, jordanes, philosophy, image, peek, boardgamegeek,
# Nearest to the: of, within, its, and, in, deseret, substantially, sov,
# Nearest to has: prototyping, lesotho, synthesiser, diversified, blackball, telford, laos, garnered,
# Nearest to american: living, hirsch, forsyth, canadian, journalist, chemist, sennett, singer,
# Nearest to have: know, nicomachean, nitijela, ponder, surpassed, researchers, mspf, childrearing,
# Nearest to will: ready, mondays, apostles, god, busy, come, constructive, inconvenience,
# Nearest to articles: juxtaposed, links, sitar, dossier, anglicanism, newspaper, troja, crocker,
# Nearest to defense: missile, sealed, jure, rumsfeld, specialized, docs, lebanese, conducting,
# Nearest to hold: unlikely, copyists, without, sixes, oncoming, sensitivities, labourers, supplementing,
# Nearest to experience: humanistic, cornerstones, conflation, phodopus, drabble, disquisitiones, heidi, rags,
# Nearest to pressure: poison, displacements, airliner, raman, liquid, bonilla, cigarette, polishing,
# Nearest to ocean: sundarbans, atlantic, trnc, zambia, magnetosphere, dar, coastlines, ghats,
# Nearest to issue: subgenius, pontifical, miguel, dhahran, samoans, eurovision, boldness, prosecuted,
# Nearest to cost: very, dateline, yeo, upgraded, overall, contemplative, market, pentium,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0063 0.0524 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0096 0.0514 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0368 0.0514 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0279 0.0510 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0613 0.0511 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0871 0.0434 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0091 0.0523 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0082 0.0516 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0260 0.0512 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9387 0.0511 sec/batch
# Nearest to that: urinate, the, ciphertext, shipwrecks, republika, investigate, revlon, monotheistic,
# Nearest to called: unitary, kolberg, maranh, charger, wirtschaftswunder, damasus, tigress, messier,
# Nearest to history: ananias, bio, philosophy, crabbe, jordanes, boardgamegeek, image, peek,
# Nearest to the: of, within, in, and, its, to, from, that,
# Nearest to has: prototyping, synthesiser, describe, heaven, blackball, garnered, whorehouse, geophysical,
# Nearest to american: living, canadian, hirsch, chemist, forsyth, journalist, singer, novelist,
# Nearest to have: know, ponder, surpassed, nicomachean, nitijela, researchers, wonderful, nozzle,
# Nearest to will: ready, god, mondays, come, said, apostles, random, couldn,
# Nearest to articles: juxtaposed, links, sitar, dossier, alimentarius, anglicanism, newspaper, crocker,
# Nearest to defense: missile, sealed, jure, rumsfeld, specialized, offense, docs, monogatari,
# Nearest to hold: copyists, without, unlikely, sixes, labourers, oncoming, sensitivities, just,
# Nearest to experience: humanistic, phodopus, cornerstones, drabble, heidi, conflation, minds, persist,
# Nearest to pressure: displacements, poison, liquid, raman, airliner, polishing, cigarette, vapor,
# Nearest to ocean: sundarbans, atlantic, trnc, magnetosphere, polluted, zambia, oligocene, tackle,
# Nearest to issue: subgenius, miguel, samoans, brewers, dhahran, boldness, pontifical, eurovision,
# Nearest to cost: overall, market, very, upgraded, dateline, decrypting, pentium, yeo,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0007 0.0533 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9698 0.0524 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0382 0.0514 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0196 0.0513 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0327 0.0507 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9971 0.0512 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8779 0.0509 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9230 0.0512 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9344 0.0509 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9399 0.0512 sec/batch
# Nearest to that: the, urinate, morphisms, investigate, even, monotheistic, ciphertext, revlon,
# Nearest to called: unitary, maranh, kolberg, charger, messier, each, handset, damasus,
# Nearest to history: bio, ananias, philosophy, italy, crabbe, jordanes, image, sra,
# Nearest to the: of, in, within, and, its, to, that, from,
# Nearest to has: prototyping, synthesiser, and, diversified, garnered, lesotho, whorehouse, unranked,
# Nearest to american: living, hirsch, forsyth, chemist, canadian, tonga, suleiman, journalist,
# Nearest to have: know, surpassed, mspf, nozzle, nicomachean, are, ponder, researchers,
# Nearest to will: ready, god, come, apostles, said, mondays, inconvenience, busy,
# Nearest to articles: links, juxtaposed, sitar, dossier, crocker, newspaper, alimentarius, forum,
# Nearest to defense: missile, sealed, jure, shelled, rumsfeld, specialized, seaver, offense,
# Nearest to hold: sixes, copyists, unlikely, oncoming, without, sensitivities, only, just,
# Nearest to experience: humanistic, phodopus, dm, cornerstones, rags, drabble, persist, conflation,
# Nearest to pressure: poison, displacements, raman, cigarette, liquid, vapor, regrouping, polishing,
# Nearest to ocean: atlantic, sundarbans, trnc, polluted, oligocene, magnetosphere, zambia, own,
# Nearest to issue: subgenius, samoans, miguel, dhahran, brewers, pontifical, eurovision, glace,
# Nearest to cost: very, decrypting, overall, contemplative, soaring, tribute, yeo, pentium,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9820 0.0522 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0146 0.0515 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9830 0.0515 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9986 0.0512 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0446 0.0518 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9695 0.0517 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9992 0.0517 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9876 0.0517 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9898 0.0517 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9905 0.0517 sec/batch
# Nearest to that: the, urinate, investigate, even, monotheistic, and, dominus, revlon,
# Nearest to called: unitary, kolberg, maranh, charger, handset, wirtschaftswunder, damasus, each,
# Nearest to history: ananias, bio, philosophy, crabbe, kenney, italy, jordanes, wiley,
# Nearest to the: of, in, within, and, its, to, that, a,
# Nearest to has: prototyping, synthesiser, and, also, blackball, a, describe, telford,
# Nearest to american: living, forsyth, chemist, hirsch, singer, journalist, canadian, suleiman,
# Nearest to have: know, surpassed, nicomachean, are, there, wonderful, mspf, sufficed,
# Nearest to will: ready, god, come, said, pending, busy, apostles, mondays,
# Nearest to articles: links, juxtaposed, sitar, dossier, newspaper, crocker, alimentarius, site,
# Nearest to defense: missile, sealed, rumsfeld, specialized, jure, offense, docs, equites,
# Nearest to hold: sixes, copyists, unlikely, without, oncoming, sensitivities, only, labourers,
# Nearest to experience: humanistic, dm, cornerstones, drabble, conflation, rationalists, phodopus, minds,
# Nearest to pressure: displacements, raman, poison, liquid, oscillator, cigarette, vapor, polishing,
# Nearest to ocean: atlantic, sundarbans, trnc, shortwave, satellite, eutelsat, magnetosphere, zambia,
# Nearest to issue: subgenius, samoans, miguel, brewers, eurovision, dhahran, pontifical, overhauled,
# Nearest to cost: very, yeo, decrypting, overall, tribute, dateline, ran, pentium,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0137 0.0526 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0006 0.0517 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9754 0.0518 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0201 0.0517 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0144 0.0516 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0070 0.0520 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9749 0.0516 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9263 0.0515 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9772 0.0513 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0104 0.0516 sec/batch
# Nearest to that: the, even, urinate, investigate, republika, morphisms, revlon, from,
# Nearest to called: unitary, kolberg, maranh, wirtschaftswunder, charger, damasus, handset, kcr,
# Nearest to history: bio, ananias, italy, overview, crabbe, philosophy, sra, evolutionism,
# Nearest to the: of, in, and, its, within, to, a, from,
# Nearest to has: prototyping, and, also, a, synthesiser, the, blackball, telford,
# Nearest to american: living, hirsch, forsyth, chemist, canadian, tonga, suleiman, sennett,
# Nearest to have: know, are, nicomachean, there, surpassed, individuals, nitijela, ponder,
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8566 0.0508 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9291 0.0511 sec/batch
# Nearest to that: the, it, to, even, and, have, be, this,
# Nearest to called: both, devised, been, differentiation, quail, antiprism, unitary, in,
# Nearest to history: external, links, liddell, times, references, daggers, naia, boardgamegeek,
# Nearest to the: of, in, and, a, to, by, s, its,
# Nearest to has: in, the, and, is, this, a, also, based,
# Nearest to american: living, driver, eddings, americans, comedians, recipients, native, sennett,
# Nearest to have: are, been, there, these, that, most, several, has,
# Nearest to will: come, ready, god, we, rev, pending, asks, inconvenience,
# Nearest to articles: links, juxtaposed, newspaper, problems, sitar, crocker, sanford, pennies,
# Nearest to defense: missile, offense, specialized, rumsfeld, shelled, equites, seaver, edwards,
# Nearest to hold: ascari, guiding, watashi, labourers, abendana, only, sixes, masorti,
# Nearest to experience: dm, persist, humanistic, turbo, bereavement, conflation, explained, rhonda,
# Nearest to pressure: displacements, liquid, mwh, polishing, genocidal, liberalisation, cigarette, saws,
# Nearest to ocean: atlantic, eutelsat, shortwave, arabsat, sundarbans, stations, satellite, own,
# Nearest to issue: matters, boldness, samoans, lessens, dea, involving, serres, housemate,
# Nearest to cost: ran, tribute, pentium, overall, very, catered, fraction, decrypting,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8262 0.0522 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8414 0.0512 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8276 0.0512 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8501 0.0512 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8787 0.0510 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8685 0.0512 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8551 0.0515 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8318 0.0510 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8776 0.0512 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8835 0.0513 sec/batch
# Nearest to that: the, it, to, have, be, and, even, of,
# Nearest to called: quail, unitary, both, devised, rigour, each, been, perpetuate,
# Nearest to history: external, links, references, historiography, times, christianity, danish, evolutionism,
# Nearest to the: of, in, and, to, a, its, by, s,
# Nearest to has: the, a, this, in, and, is, existence, have,
# Nearest to american: living, driver, americans, recipients, sennett, eddings, comedians, native,
# Nearest to have: are, been, there, that, these, most, they, in,
# Nearest to will: come, god, we, ready, pending, atb, rev, believe,
# Nearest to articles: links, juxtaposed, newspaper, problems, sitar, crocker, article, pennies,
# Nearest to defense: missile, offense, specialized, shelled, rumsfeld, equites, seaver, docs,
# Nearest to hold: ascari, labourers, guiding, watashi, abendana, sixes, masorti, membership,
# Nearest to experience: dm, persist, conflation, turbo, rhonda, humanistic, explained, linguistique,
# Nearest to pressure: displacements, liquid, genocidal, liberalisation, harun, polishing, mwh, explosions,
# Nearest to ocean: atlantic, eutelsat, shortwave, arabsat, sundarbans, satellite, stations, polluted,
# Nearest to issue: matters, samoans, boldness, biblically, serres, brewers, rebuttals, pieter,
# Nearest to cost: ran, tribute, fraction, pentium, overall, decrypting, very, catered,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8606 0.0524 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8526 0.0510 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8681 0.0513 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8222 0.0512 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9020 0.0511 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8051 0.0511 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9570 0.0511 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9192 0.0511 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9358 0.0514 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8522 0.0508 sec/batch
# Nearest to that: it, the, to, be, have, and, even, this,
# Nearest to called: quail, been, both, devised, each, unitary, commenced, differentiation,
# Nearest to history: external, links, historiography, references, overview, times, golconda, naia,
# Nearest to the: of, in, and, a, to, by, its, s,
# Nearest to has: the, in, a, and, this, is, have, it,
# Nearest to american: living, driver, recipients, americans, sennett, u, singer, eddings,
# Nearest to have: are, been, these, there, that, some, most, and,
# Nearest to will: come, god, ready, we, pending, be, do, atb,
# Nearest to articles: links, juxtaposed, newspaper, problems, sitar, article, sanford, waldeck,
# Nearest to defense: missile, offense, specialized, rumsfeld, shelled, equites, seaver, edwards,
# Nearest to hold: ascari, labourers, guiding, watashi, masorti, excommunicating, only, waging,
# Nearest to experience: dm, persist, rhonda, turbo, humanistic, conflation, banzer, bereavement,
# Nearest to pressure: displacements, harun, polishing, liquid, mwh, genocidal, liberalisation, saws,
# Nearest to ocean: atlantic, eutelsat, shortwave, arabsat, sundarbans, satellite, stations, radios,
# Nearest to issue: matters, boldness, recess, unanimously, serres, rebuttals, pieter, biblically,
# Nearest to cost: ran, tribute, fraction, pentium, overall, upgrade, very, yank,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8155 0.0517 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8492 0.0507 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7756 0.0511 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8675 0.0509 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8655 0.0512 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8316 0.0509 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9254 0.0205 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8030 0.0506 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8173 0.0509 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8367 0.0511 sec/batch
# Nearest to that: it, the, to, and, have, be, even, of,
# Nearest to called: quail, been, both, unitary, devised, commenced, handset, rigour,
# Nearest to history: external, links, references, times, historiography, christianity, golconda, by,
# Nearest to the: of, in, and, a, to, by, its, is,
# Nearest to has: in, have, is, it, a, this, and, the,
# Nearest to american: driver, singer, living, u, novelist, canadian, americans, chemist,
# Nearest to have: are, been, these, that, there, most, in, and,
# Nearest to will: come, god, ready, we, rev, our, believe, plasmodium,
# Nearest to articles: links, juxtaposed, problems, newspaper, sitar, references, crocker, severely,
# Nearest to defense: missile, offense, equites, specialized, shelled, rumsfeld, seaver, intercepting,
# Nearest to hold: ascari, watashi, labourers, waging, excommunicating, masorti, guiding, abendana,
# Nearest to experience: dm, persist, rhonda, humanistic, bereavement, turbo, banzer, linguistique,
# Nearest to pressure: displacements, liquid, mwh, polishing, harun, saws, genocidal, liberalisation,
# Nearest to ocean: atlantic, eutelsat, shortwave, sundarbans, arabsat, satellite, own, polluted,
# Nearest to issue: matters, boldness, serres, recess, pieter, unanimously, biblically, dea,
# Nearest to cost: ran, fraction, pentium, tribute, overall, upgrade, decrypting, yank,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8518 0.0523 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8012 0.0511 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8212 0.0513 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8005 0.0518 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8520 0.0514 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8605 0.0510 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8835 0.0513 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7685 0.0512 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7901 0.0510 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8221 0.0511 sec/batch
# Nearest to that: it, the, to, be, have, not, and, this,
# Nearest to called: both, quail, the, and, unitary, devised, in, a,
# Nearest to history: external, links, references, by, times, map, overview, of,
# Nearest to the: of, in, and, a, by, to, its, is,
# Nearest to has: in, the, and, this, have, is, it, a,
# Nearest to american: living, americans, native, driver, recipients, pashto, u, relocation,
# Nearest to have: are, been, these, in, that, and, there, some,
# Nearest to will: come, god, believe, we, ready, our, do, prophets,
# Nearest to articles: links, juxtaposed, problems, newspaper, sitar, references, crocker, sanford,
# Nearest to defense: missile, offense, equites, specialized, shelled, rumsfeld, intercepting, seaver,
# Nearest to hold: ascari, watashi, guiding, waging, masorti, decks, membership, only,
# Nearest to experience: persist, dm, bereavement, rhonda, turbo, banzer, humanistic, perception,
# Nearest to pressure: polishing, displacements, liquid, mwh, liberalisation, saws, genocidal, harun,
# Nearest to ocean: atlantic, eutelsat, arabsat, sundarbans, shortwave, own, satellite, oceanic,
# Nearest to issue: matters, serres, pieter, boldness, biblically, housemate, recess, lessens,
# Nearest to cost: ran, fraction, tribute, pentium, overall, decrypting, upgrade, catered,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7447 0.0518 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8309 0.0518 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8622 0.0527 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8268 0.0511 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8005 0.0507 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8931 0.0507 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8521 0.0507 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8009 0.0507 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8251 0.0508 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8273 0.0510 sec/batch
# Nearest to that: it, the, to, be, this, been, have, and,
# Nearest to called: quail, both, been, unitary, in, considered, devised, and,
# Nearest to history: external, links, references, naia, liddell, historiography, overview, map,
# Nearest to the: of, in, and, a, is, by, its, to,
# Nearest to has: in, the, is, and, a, this, also, based,
# Nearest to american: living, americans, native, driver, recipients, pashto, eddings, comedians,
# Nearest to have: are, been, these, there, that, and, some, in,
# Nearest to will: come, god, believe, ready, all, plasmodium, really, we,
# Nearest to articles: links, juxtaposed, problems, newspaper, sitar, article, sanford, crocker,
# Nearest to defense: missile, offense, specialized, equites, shelled, rumsfeld, docs, jilted,
# Nearest to hold: ascari, guiding, only, membership, masorti, excommunicating, waging, watashi,
# Nearest to experience: dm, persist, humanistic, turbo, rhonda, perception, bereavement, gyeonggi,
# Nearest to pressure: liquid, displacements, polishing, mwh, liberalisation, harun, cigarette, genocidal,
# Nearest to ocean: atlantic, eutelsat, shortwave, sundarbans, arabsat, satellite, own, voyages,
# Nearest to issue: matters, serres, biblically, dc, involving, recess, pieter, housemate,
# Nearest to cost: fraction, tribute, overall, ran, pentium, interdependent, poorer, decrypting,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8755 0.0521 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8133 0.0508 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8127 0.0513 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8668 0.0511 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8427 0.0508 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8754 0.0512 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8390 0.0510 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8736 0.0513 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7820 0.0510 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8221 0.0509 sec/batch
# Nearest to that: it, the, to, be, this, have, and, of,
# Nearest to called: both, quail, devised, and, the, in, each, unitary,
# Nearest to history: external, links, references, historiography, overview, christianity, map, naia,
# Nearest to the: of, in, and, a, to, by, is, its,
# Nearest to has: in, the, and, is, a, this, for, by,
# Nearest to american: living, americans, recipients, native, states, driver, pashto, eddings,
# Nearest to have: are, been, these, there, that, some, in, and,
# Nearest to will: come, god, believe, ready, we, do, plasmodium, all,
# Nearest to articles: links, newspaper, juxtaposed, problems, article, sanford, sitar, crocker,
# Nearest to defense: missile, offense, specialized, equites, shelled, rumsfeld, docs, faxing,
# Nearest to hold: ascari, only, masorti, guiding, membership, watashi, excommunicating, powers,
# Nearest to experience: dm, persist, rhonda, humanistic, bereavement, turbo, gyeonggi, banzer,
# Nearest to pressure: displacements, polishing, liquid, harun, liberalisation, mwh, ratings, pressures,
# Nearest to ocean: atlantic, eutelsat, sundarbans, shortwave, arabsat, voyages, oceanic, landfall,
# Nearest to issue: matters, biblically, serres, pieter, recess, recognizer, dc, boldness,
# Nearest to cost: fraction, ran, tribute, pentium, overall, cheap, poorer, decrypting,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8329 0.0520 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8271 0.0509 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8974 0.0513 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8940 0.0512 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9003 0.0512 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8496 0.0529 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7746 0.0530 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8521 0.0528 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7202 0.0521 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8485 0.0510 sec/batch
# Nearest to that: it, the, to, be, have, not, this, because,
# Nearest to called: both, been, quail, devised, unitary, handset, each, in,
# Nearest to history: external, links, references, historiography, overview, naia, map, times,
# Nearest to the: of, in, and, to, a, its, is, by,
# Nearest to has: in, the, is, and, a, this, for, also,
# Nearest to american: living, recipients, driver, americans, u, postmodernists, singer, canadian,
# Nearest to have: are, been, these, there, that, some, most, several,
# Nearest to will: come, god, we, do, our, plasmodium, ready, be,
# Nearest to articles: links, newspaper, juxtaposed, problems, sitar, biography, sanford, formulario,
# Nearest to defense: missile, offense, specialized, equites, shelled, rumsfeld, crimes, docs,
# Nearest to hold: ascari, watashi, masorti, membership, guiding, only, excellency, waging,
# Nearest to experience: dm, persist, rhonda, humanistic, perception, bereavement, banzer, turbo,
# Nearest to pressure: harun, polishing, ratings, displacements, liberalisation, saws, mwh, liquid,
# Nearest to ocean: atlantic, eutelsat, shortwave, arabsat, sundarbans, satellite, stations, mars,
# Nearest to issue: matters, pieter, recess, serres, biblically, recognizer, dc, housemate,
# Nearest to cost: fraction, ran, pentium, tribute, overall, decrypting, hydroponics, cheap,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8522 0.0524 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8309 0.0527 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
